# %%
import sys
import os

# Thêm thư mục gốc của project vào sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"Project root added: {project_root}")
# Out:
# Project root added: /Users/khangbinhdl/HK V/Python cho KHDL/Cuối kì

# %%
from src.visualization.eda import EDA
from src.data.preprocessor import DataPreprocessor

# %%
FILE_PATH = '../data/raw/FastFoodNutritionMenuV3.csv'

# %% [markdown]
# # EDA trên các cột mà ta sử dụng

# %%
prep = DataPreprocessor()
prep.load_data(FILE_PATH, auto_convert_numeric=True)
prep.convert_to_datetime()
# Out:
# DataPreprocessor(num='median', cat='mode', dt='drop', scaling='standard', outlier='iqr')

# %%
# Bỏ các cột không cần thiết
drop_features = ['calories_from_fat', 'weight_watchers_pnts', 'company', 'item', 'total_fat_g', 'calories', 'trans_fat_g']
prep.drop_features(drop_features)
# Out:
# DataPreprocessor(num='median', cat='mode', dt='drop', scaling='standard', outlier='iqr')

# %%
data_after_drop = prep.get_processed_data()
eda_drop = EDA(data_after_drop, show_plots=True)
eda_drop.perform_eda(corr_method='all', save_path=None)
