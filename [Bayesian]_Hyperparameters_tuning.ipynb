# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import optuna

# %%
X, y = fetch_california_housing(return_X_y=True, as_frame=False)
print("Dataset shape:", X.shape)
# Out:
# Dataset shape: (20640, 8)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

def objective(trial: optuna.Trial) -> float:
    n_estimators = trial.suggest_int("n_estimators", 100, 1000, step=100)
    max_depth = trial.suggest_int("max_depth", 5, 35)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 10)
    max_features = trial.suggest_float("max_features", 0.2, 1.0, step=0.1)

    rf = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        n_jobs=-1,
        random_state=42
    )

    scores = []
    for train_idx, valid_idx in kf.split(X):
        X_train, X_valid = X[train_idx], X[valid_idx]
        y_train, y_valid = y[train_idx], y[valid_idx]

        rf.fit(X_train, y_train)
        preds = rf.predict(X_valid)
        mse = mean_squared_error(y_valid, preds)
        scores.append(mse)

        trial.report(np.mean(scores), step=len(scores))
        if trial.should_prune():
            raise optuna.TrialPruned()

    return np.mean(scores)

# %%
study = optuna.create_study(
    study_name="rf_regression_opt",
    direction="minimize",  # minimize MSE
    sampler=optuna.samplers.TPESampler(seed=42),
    pruner=optuna.pruners.MedianPruner(),
)
study.optimize(objective, n_trials=50, n_jobs=-1)
# Out:
# [I 2025-11-12 08:29:11,860] A new study created in memory with name: rf_regression_opt
# [I 2025-11-12 08:29:34,566] Trial 1 finished with value: 0.25521564462996793 and parameters: {'n_estimators': 100, 'max_depth': 33, 'min_samples_split': 18, 'min_samples_leaf': 4, 'max_features': 0.6000000000000001}. Best is trial 1 with value: 0.25521564462996793.
# [I 2025-11-12 08:29:54,765] Trial 8 finished with value: 0.5778870721101559 and parameters: {'n_estimators': 700, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 0.2}. Best is trial 1 with value: 0.25521564462996793.
# [I 2025-11-12 08:30:09,445] Trial 4 finished with value: 0.25633679397839815 and parameters: {'n_estimators': 200, 'max_depth': 16, 'min_samples_split': 17, 'min_samples_leaf': 2, 'max_features': 0.8}. Best is trial 1 with value: 0.25521564462996793.
# [I 2025-11-12 08:30:21,326] Trial 5 finished with value: 0.26737656304002266 and parameters: {'n_estimators': 300, 'max_depth': 19, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 0.7}. Best is trial 1 with value: 0.25521564462996793.
# [I 2025-11-12 08:30:24,564] Trial 9 finished with value: 0.2830738854947268 and parameters: {'n_estimators': 600, 'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 0.30000000000000004}. Best is trial 1 with value: 0.25521564462996793.
# [I 2025-11-12 08:30:32,325] Trial 6 finished with value: 0.26184469269199345 and parameters: {'n_estimators': 400, 'max_depth': 24, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_features': 0.5}. Best is trial 1 with value: 0.25521564462996793.
# [I 2025-11-12 08:30:32,332] Trial 7 finished with value: 0.2624865207978405 and parameters: {'n_estimators': 500, 'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 0.4}. Best is trial 1 with value: 0.25521564462996793.
# [I 2025-11-12 08:30:33,823] Trial 0 pruned.
# [I 2025-11-12 08:30:34,495] Trial 13 pruned.
# [I 2025-11-12 08:30:44,975] Trial 2 pruned.
# [I 2025-11-12 08:30:58,069] Trial 18 finished with value: 0.24431125721964847 and parameters: {'n_estimators': 100, 'max_depth': 34, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 0.6000000000000001}. Best is trial 18 with value: 0.24431125721964847.
# [I 2025-11-12 08:30:58,239] Trial 11 pruned.
# [I 2025-11-12 08:31:11,653] Trial 10 finished with value: 0.26151128963910375 and parameters: {'n_estimators': 300, 'max_depth': 19, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 0.9000000000000001}. Best is trial 18 with value: 0.24431125721964847.
# [I 2025-11-12 08:31:19,614] Trial 21 finished with value: 0.24888847235214398 and parameters: {'n_estimators': 100, 'max_depth': 34, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 0.6000000000000001}. Best is trial 18 with value: 0.24431125721964847.
# [I 2025-11-12 08:31:20,042] Trial 20 finished with value: 0.24810731514038203 and parameters: {'n_estimators': 100, 'max_depth': 35, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 0.6000000000000001}. Best is trial 18 with value: 0.24431125721964847.
# [I 2025-11-12 08:31:29,733] Trial 14 pruned.
# [I 2025-11-12 08:31:33,682] Trial 22 finished with value: 0.24810731514038203 and parameters: {'n_estimators': 100, 'max_depth': 35, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.6000000000000001}. Best is trial 18 with value: 0.24431125721964847.
# [I 2025-11-12 08:31:35,236] Trial 12 finished with value: 0.2520911410745965 and parameters: {'n_estimators': 400, 'max_depth': 31, 'min_samples_split': 18, 'min_samples_leaf': 3, 'max_features': 0.5}. Best is trial 18 with value: 0.24431125721964847.
# [I 2025-11-12 08:31:41,591] Trial 23 finished with value: 0.24810731514038203 and parameters: {'n_estimators': 100, 'max_depth': 34, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.6000000000000001}. Best is trial 18 with value: 0.24431125721964847.
# [I 2025-11-12 08:31:50,101] Trial 27 pruned.
# [I 2025-11-12 08:31:54,007] Trial 17 pruned.
# [I 2025-11-12 08:31:56,783] Trial 28 pruned.
# [I 2025-11-12 08:32:14,696] Trial 30 pruned.
# [I 2025-11-12 08:32:28,370] Trial 16 finished with value: 0.25096977553604527 and parameters: {'n_estimators': 300, 'max_depth': 31, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 0.9000000000000001}. Best is trial 18 with value: 0.24431125721964847.
# [I 2025-11-12 08:32:29,867] Trial 24 finished with value: 0.2432992941302662 and parameters: {'n_estimators': 300, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.5}. Best is trial 24 with value: 0.2432992941302662.
# [I 2025-11-12 08:32:42,880] Trial 31 finished with value: 0.2440208886739673 and parameters: {'n_estimators': 200, 'max_depth': 35, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.5}. Best is trial 24 with value: 0.2432992941302662.
# [I 2025-11-12 08:32:46,662] Trial 3 finished with value: 0.2509828821088517 and parameters: {'n_estimators': 700, 'max_depth': 23, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.8}. Best is trial 24 with value: 0.2432992941302662.
# [I 2025-11-12 08:32:54,191] Trial 25 finished with value: 0.2472569005407042 and parameters: {'n_estimators': 300, 'max_depth': 29, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.7}. Best is trial 24 with value: 0.2432992941302662.
# [I 2025-11-12 08:32:56,674] Trial 26 finished with value: 0.2472569005407042 and parameters: {'n_estimators': 300, 'max_depth': 29, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.7}. Best is trial 24 with value: 0.2432992941302662.
# [I 2025-11-12 08:32:57,397] Trial 29 finished with value: 0.245604377434698 and parameters: {'n_estimators': 200, 'max_depth': 29, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.7}. Best is trial 24 with value: 0.2432992941302662.
# [I 2025-11-12 08:33:03,327] Trial 32 finished with value: 0.2418501998462733 and parameters: {'n_estimators': 200, 'max_depth': 35, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 32 with value: 0.2418501998462733.
# [I 2025-11-12 08:33:16,599] Trial 33 finished with value: 0.2440208886739673 and parameters: {'n_estimators': 200, 'max_depth': 35, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.5}. Best is trial 32 with value: 0.2418501998462733.
# [I 2025-11-12 08:33:20,302] Trial 34 finished with value: 0.2408282726522823 and parameters: {'n_estimators': 200, 'max_depth': 32, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 34 with value: 0.2408282726522823.
# [I 2025-11-12 08:33:33,275] Trial 35 finished with value: 0.24225072805417489 and parameters: {'n_estimators': 200, 'max_depth': 27, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 34 with value: 0.2408282726522823.
# [I 2025-11-12 08:33:37,433] Trial 36 finished with value: 0.2406973598440414 and parameters: {'n_estimators': 200, 'max_depth': 27, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 36 with value: 0.2406973598440414.
# [I 2025-11-12 08:33:44,299] Trial 37 finished with value: 0.2408282726522823 and parameters: {'n_estimators': 200, 'max_depth': 32, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 36 with value: 0.2406973598440414.
# [I 2025-11-12 08:33:48,224] Trial 38 finished with value: 0.24181585870599126 and parameters: {'n_estimators': 200, 'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 36 with value: 0.2406973598440414.
# [I 2025-11-12 08:33:52,998] Trial 40 finished with value: 0.24181585870599126 and parameters: {'n_estimators': 200, 'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 36 with value: 0.2406973598440414.
# [I 2025-11-12 08:34:07,080] Trial 41 finished with value: 0.24248771474828756 and parameters: {'n_estimators': 200, 'max_depth': 32, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 36 with value: 0.2406973598440414.
# [I 2025-11-12 08:34:13,745] Trial 15 pruned.
# [I 2025-11-12 08:34:29,533] Trial 19 finished with value: 0.24564625737042842 and parameters: {'n_estimators': 1000, 'max_depth': 35, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 0.6000000000000001}. Best is trial 36 with value: 0.2406973598440414.
# [I 2025-11-12 08:34:41,226] Trial 42 finished with value: 0.2380300166325348 and parameters: {'n_estimators': 400, 'max_depth': 32, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 0.4}. Best is trial 42 with value: 0.2380300166325348.
# [I 2025-11-12 08:34:51,741] Trial 43 finished with value: 0.23716200093490367 and parameters: {'n_estimators': 400, 'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.4}. Best is trial 43 with value: 0.23716200093490367.
# [I 2025-11-12 08:34:53,671] Trial 44 finished with value: 0.23757304934508988 and parameters: {'n_estimators': 400, 'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 0.4}. Best is trial 43 with value: 0.23716200093490367.
# [I 2025-11-12 08:34:55,667] Trial 39 finished with value: 0.24036712304494015 and parameters: {'n_estimators': 500, 'max_depth': 32, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.5}. Best is trial 43 with value: 0.23716200093490367.
# [I 2025-11-12 08:34:56,168] Trial 45 finished with value: 0.23803001663253487 and parameters: {'n_estimators': 400, 'max_depth': 32, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 0.4}. Best is trial 43 with value: 0.23716200093490367.
# [I 2025-11-12 08:34:58,086] Trial 46 finished with value: 0.2380300166325348 and parameters: {'n_estimators': 400, 'max_depth': 32, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 0.4}. Best is trial 43 with value: 0.23716200093490367.
# [I 2025-11-12 08:34:59,233] Trial 47 finished with value: 0.23935294455141826 and parameters: {'n_estimators': 400, 'max_depth': 32, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 0.4}. Best is trial 43 with value: 0.23716200093490367.
# [I 2025-11-12 08:35:03,436] Trial 49 finished with value: 0.23704824192474555 and parameters: {'n_estimators': 400, 'max_depth': 27, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.4}. Best is trial 49 with value: 0.23704824192474555.
# [I 2025-11-12 08:35:03,529] Trial 48 finished with value: 0.2350993214394105 and parameters: {'n_estimators': 400, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.4}. Best is trial 48 with value: 0.2350993214394105.

# %%
print("Best trial:")
print(f"  Value (MSE): {study.best_value}")
print(f"  Params: {study.best_params}")
# Out:
# Best trial:
#   Value (MSE): 0.2350993214394105
#   Params: {'n_estimators': 400, 'max_depth': 25, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.4}

# %%
best_params = study.best_params
final_rf = RandomForestRegressor(
    **best_params,
    n_jobs=-1,
    random_state=42
)

# Huấn luyện model trên TOÀN BỘ dữ liệu X và y
final_rf.fit(X, y)
# Out:
# RandomForestRegressor(max_depth=25, max_features=0.4, min_samples_split=3,
#                       n_estimators=400, n_jobs=-1, random_state=42)

# %%
y_pred = final_rf.predict(X)
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# %%
print("\nFinal model performance on the entire dataset:")
print(f"  Mean Absolute Error (MAE): {mae}")
print(f"  Mean Squared Error (MSE): {mse}")
print(f"  R^2 Score: {r2}")
# Out:
# Final model performance on the entire dataset:
#   Mean Absolute Error (MAE): 0.12324952756442711
#   Mean Squared Error (MSE): 0.03635377507902487
#   R^2 Score: 0.9726981586224783

# %%
from optuna.importance import get_param_importances
importances = get_param_importances(study)
print("\nParam importances:")
for p, imp in importances.items():
    print(f"{p:25s}: {imp:.3f}")
# Out:
# Param importances:
# max_depth                : 0.364
# max_features             : 0.304
# min_samples_split        : 0.241
# min_samples_leaf         : 0.075
# n_estimators             : 0.016
